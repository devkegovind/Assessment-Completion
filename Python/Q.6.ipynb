# %% [markdown]
# Q.6. Using the data from Question 3, write code to analyze the data and answer the following questions
# Note
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations.
# 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# - Get all Pokemons whose spawn rate is less than 5%
# - Get all Pokemons that have less than 4 weaknesses
# - Get all Pokemons that have no multipliers at all
# - Get all Pokemons that do not have more than 2 evolutions
# - Get all Pokemons whose spawn time is less than 300 seconds.
# Note - spawn time format is "05:32”, so assume “minute: second” format and perform the analysis.
# - Get all Pokemon who have more than two types of capabilities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl

# %%
df = pd.read_excel("D:\\Downloads\\pokedex.xlsx")

# %%
df
# Out:
#            Name                                             Image  \
# 0     Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1       Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3    Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4    Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# ..          ...                                               ...
# 146     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                Type  Height    Weight             Candy  candy_count  \
# 0     Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# ...

# %% [markdown]
# **Get all Pokémon whose spawn rate is less than 5%**

# %%
df[df['spawn_chance'] < 5]
# Out:
#            Name                                             Image  \
# 0     Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1       Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3    Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4    Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# ..          ...                                               ...
# 146     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#                Type  Height    Weight             Candy  candy_count  \
# 0     Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# ...

# %% [markdown]
# **Plotting the Analysis**

# %% [markdown]
# *Bar plot for Pokémon spawn rate less than 5%*

# %%
plt.figure(figsize=(25, 6))
plt.bar(df[df['spawn_chance'] < 5]['Name'], df[df['spawn_chance'] < 5]['spawn_chance'])
plt.xlabel('Pokémon')
plt.ylabel('Spawn Rate (%)')
plt.title('Pokémon with Spawn Rate Less Than 5%')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# 1. There are 148 Pokémon with spawn rate less than 5%

# %% [markdown]
# **Get all Pokémon that have less than 4 weaknesses**

# %%
df['Total_Weekness'] = df['weaknesses'].str.split(', ').apply(lambda x: len(x) if isinstance(x, list) else 0)

# %%
df.head()
# Out:
#          Name                                             Image  \
# 0   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#             Type  Height    Weight             Candy  candy_count  \
# 0  Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  Grass, Poison  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  Grass, Poison  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           Fire  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           Fire  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# 0         2 km         0.690        69.0      20:00        1.58
# ...

# %%
df[df['Total_Weekness'] < 4]
# Out:
#            Name                                             Image  \
# 3    Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4    Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5     Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 6      Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 7     Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..          ...                                               ...
# 145     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 146     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 149      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
#              Type  Height    Weight             Candy  candy_count  \
# 3            Fire  0.61 m    8.5 kg  Charmander Candy         25.0
# ...

# %% [markdown]
# *Bar plot for Pokémon with less than 4 weaknesses*

# %%
plt.figure(figsize=(25, 6))
plt.bar(df[df['Total_Weekness'] < 4]['Name'], df[df['Total_Weekness'] < 4]['Total_Weekness'])
plt.xlabel('Pokémon')
plt.ylabel('Number of Weaknesses')
plt.title('Pokémon with Less Than 4 Weaknesses')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# 1. There are 102 Pokémon with less than 4 weaknesses

# %% [markdown]
# **Get all Pokémon that have no multipliers at all**

# %%
df[df['multipliers'] == 0]
# Out:
# Empty DataFrame
# Columns: [Name, Image, Type, Height, Weight, Candy, candy_count, egg, spawn_chance, avg_spawns, spawn_time, multipliers, weaknesses, Next_evolution, Prev_evolution, Total_Weekness]
# Index: []

# %% [markdown]
# *Get all Pokémon that have no multipliers at all*

# %% [markdown]
# *Bar plot for Pokémon with no multipliers*

# %%
plt.figure(figsize=(10, 6))
plt.bar(df[df['multipliers'] == 0]['Name'], 0)
plt.xlabel('Pokémon')
plt.ylabel('No Multipliers')
plt.title('Pokémon with No Multipliers')
plt.xticks(rotation=90)
plt.yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# 1. There are 81 Pokémon with no multipliers

# %% [markdown]
# **Get all Pokémon that do not have more than 2 evolutions**

# %%
df['Next_evolution'].unique()
# Out:
# array(['Ivysaur, Venusaur', 'Venusaur', nan, 'Charmeleon, Charizard',
#        'Charizard', 'Wartortle, Blastoise', 'Blastoise',
#        'Metapod, Butterfree', 'Butterfree', 'Kakuna, Beedrill',
#        'Beedrill', 'Pidgeotto, Pidgeot', 'Pidgeot', 'Raticate', 'Fearow',
#        'Arbok', 'Raichu', 'Sandslash', 'Nidorina, Nidoqueen', 'Nidoqueen',
#        'Nidorino, Nidoking', 'Nidoking', 'Clefable', 'Ninetales',
#        'Wigglytuff', 'Golbat', 'Gloom, Vileplume', 'Vileplume',
#        'Parasect', 'Venomoth', 'Dugtrio', 'Persian', 'Golduck',
#        'Primeape', 'Arcanine', 'Poliwhirl, Poliwrath', 'Poliwrath',
#        'Kadabra, Alakazam', 'Alakazam', 'Machoke, Machamp', 'Machamp',
#        'Weepinbell, Victreebel', 'Victreebel', 'Tentacruel',
#        'Graveler, Golem', 'Golem', 'Rapidash', 'Slowbro', 'Magneton',
#        'Dodrio', 'Dewgong', 'Muk', 'Cloyster', 'Haunter, Gengar',
#        'Gengar', 'Hypno', 'Kingler', 'Electrode', 'Exeggutor', 'Marowak',
# ...

# %%
# Create the "evol1" column by splitting df['Next_evolution'] and counting the total items
df['evol1'] = df['Next_evolution'].str.split(', ').apply(lambda x: len(x) if isinstance(x, list) else 0)

# Replace NaN values in the "evol1" column with 0
df['evol1'].fillna(0, inplace=True)

# %%
df.head()
# Out:
#          Name                                             Image  \
# 0   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#             Type  Height    Weight             Candy  candy_count  \
# 0  Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  Grass, Poison  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  Grass, Poison  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           Fire  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           Fire  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# 0         2 km         0.690        69.0      20:00        1.58
# ...

# %%
# Create the "evol1" column by splitting df['Next_evolution'] and counting the total items
df['evol2'] = df['Prev_evolution'].str.split(', ').apply(lambda x: len(x) if isinstance(x, list) else 0)

# Replace NaN values in the "evol1" column with 0
df['evol2'].fillna(0, inplace=True)

# %%
df.head()
# Out:
#          Name                                             Image  \
# 0   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#             Type  Height    Weight             Candy  candy_count  \
# 0  Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  Grass, Poison  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  Grass, Poison  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           Fire  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           Fire  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# 0         2 km         0.690        69.0      20:00        1.58
# ...

# %%
df['evol3'] = df['evol2'] + df['evol1']

# %%
df.head()
# Out:
#          Name                                             Image  \
# 0   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#             Type  Height    Weight             Candy  candy_count  \
# 0  Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  Grass, Poison  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  Grass, Poison  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           Fire  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           Fire  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# 0         2 km         0.690        69.0      20:00        1.58
# ...

# %% [markdown]
# **Get all Pokémon that do not have more than 2 evolutions**

# %%
df[df['evol3'] >= 2]
# Out:
#                    Name                                             Image  \
# 0             Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1               Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2              Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3            Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4            Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5             Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 6              Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 7             Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# 8             Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 9              Caterpie  http://www.serebii.net/pokemongo/pokemon/010.png
# 10              Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 11           Butterfree  http://www.serebii.net/pokemongo/pokemon/012.png
# ...

# %% [markdown]
# There are 49 Pokémon that do not have more than 2 evolutions.

# %% [markdown]
# *Bar plot for Pokémon with less than 2 evolutions*

# %%
plt.figure(figsize=(10, 6))
plt.bar(df[df['evol3'] >= 2]['Name'], df[df['evol3'] >= 2]['evol3'])
plt.xlabel('Pokémon')
plt.ylabel('Number of Evolutions')
plt.title('Pokémon with Less Than 2 Evolutions')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# 1. There are 49 Pokémon that do not have more than 2 evolutions

# %%
# Convert spawn time to seconds and get all Pokémon whose spawn time is less than 300 seconds
df['spawn_time'] = pd.to_datetime(df['spawn_time'], format="%M:%S").dt.second
spawn_time_less_than_300 = df[df['spawn_time'] < 300]
print("Pokémon with spawn time less than 300 seconds:")
spawn_time_less_than_300.head()
# Out:
# Pokémon with spawn time less than 300 seconds:
#          Name                                             Image  \
# 0   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#             Type  Height    Weight             Candy  candy_count  \
# 0  Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  Grass, Poison  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  Grass, Poison  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           Fire  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           Fire  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns  spawn_time multipliers  \
# 0         2 km         0.690        69.0         0.0        1.58
# ...

# %% [markdown]
# *Bar plot for Pokémon with spawn time less than 300 seconds*

# %%
plt.figure(figsize=(35, 15))
plt.bar(spawn_time_less_than_300['Name'], spawn_time_less_than_300['spawn_time'])
plt.xlabel('Pokémon')
plt.ylabel('Spawn Time (seconds)')
plt.title('Pokémon with Spawn Time Less Than 300 seconds')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# 1. There are 145 Pokémon with Spawn Time Less Than 300 seconds

# %% [markdown]
# **Get all Pokémon who have more than two types of capabilities**

# %%
df['types_count'] = df['Type'].str.split(', ').apply(lambda x: len(x) if isinstance(x, list) else 0)
df.head()
# Out:
#          Name                                             Image  \
# 0   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#             Type  Height    Weight             Candy  candy_count  \
# 0  Grass, Poison  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  Grass, Poison  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  Grass, Poison  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           Fire  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           Fire  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns  spawn_time multipliers  \
# 0         2 km         0.690        69.0         0.0        1.58
# ...

# %%
df[df['types_count'] > 2]
# Out:
# Empty DataFrame
# Columns: [Name, Image, Type, Height, Weight, Candy, candy_count, egg, spawn_chance, avg_spawns, spawn_time, multipliers, weaknesses, Next_evolution, Prev_evolution, Total_Weekness, evol1, evol2, evol3, types_count]
# Index: []

# %% [markdown]
# *Bar plot for Pokémon with more than two types of capabilities*

# %%
plt.figure(figsize=(10, 6))
plt.bar(df[df['types_count'] > 2].index, df[df['types_count'] > 2].values)
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Pokémon with More Than Two Types of Capabilities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
# 1. No Pokémon with More Than Two Types of Capabilities
